# %%
import pandas as pd

# %%
lap=pd.read_csv('laptops.csv',encoding ='latin1')

# %% [markdown]
#  1 isin() single filtering

# %%
# select hp or apple laptops
lap.head(2)
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
#
#                                Screen                   CPU  RAM  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
#
#   Operating System Version  Weight Price (Euros)
# 0                      NaN  1.37kg       1339,69
# 1                      NaN  1.34kg        898,94

# %%
filter1=lap['Manufacturer'].isin(['Apple','HP'])# show only hp or apple laptops

# %%
lap[lap['Manufacturer'].isin(['Apple','HP'])].value_counts('Manufacturer')
# Out:
# Manufacturer
# HP       274
# Apple     21
# Name: count, dtype: int64

# %%
# multiple filetering

# %%
filter2=lap['Category'].isin(['Notebook','Ultrabook'])

# %%
lap[filter1&filter2]
# Out:
#      Manufacturer                           Model Name   Category Screen Size  \
# 0           Apple                          MacBook Pro  Ultrabook       13.3"
# 1           Apple                          Macbook Air  Ultrabook       13.3"
# 2              HP                               250 G6   Notebook       15.6"
# 3           Apple                          MacBook Pro  Ultrabook       15.4"
# 4           Apple                          MacBook Pro  Ultrabook       13.3"
# ...           ...                                  ...        ...         ...
# 1273           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook       15.6"
# 1280           HP                  Pavilion 15-AW003nv   Notebook       15.6"
# 1287           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook       15.6"
# 1294           HP                  Pavilion 15-AW003nv   Notebook       15.6"
# 1301           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook       15.6"
#
# ...

# %%
#duplicate

# %%
# find duplicates in 1 column/series
lap.head(1)
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                   CPU  RAM    Storage  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB  128GB SSD
#
#                             GPU Operating System Operating System Version  \
# 0  Intel Iris Plus Graphics 640            macOS                      NaN
#
#    Weight Price (Euros)
# 0  1.37kg       1339,69

# %%
pip=lap.duplicated(['Manufacturer','Price (Euros)','Weight'])

# %%
lap[pip]
# Out:
#      Manufacturer                                   Model Name  \
# 138        Lenovo                           IdeaPad 320-15IKBN
# 212            HP        15-bs018nq (i3-6006U/4GB/500GB/FHD/No
# 303        Lenovo                           IdeaPad 320-15IKBN
# 364        Lenovo                            IdeaPad 320-15ISK
# 366          Dell                                Inspiron 5770
# 432        Lenovo                           IdeaPad 320s-14IKB
# 550        Lenovo                            IdeaPad 320-15ISK
# 625        Lenovo                            IdeaPad 320-15IKB
# 633        Lenovo                            Ideapad 320-15ISK
# 673        Lenovo                            IdeaPad 320-15AST
# 701        Lenovo                            IdeaPad 320-15AST
# 756            HP                15-cb003na (i5-7300HQ/8GB/1TB
# 930        Lenovo                            IdeaPad 320-15IAP
# 945        Lenovo                           IdeaPad Y700-15ACZ
# ...
