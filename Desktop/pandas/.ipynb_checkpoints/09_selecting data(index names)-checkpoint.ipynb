# %%
import numpy as np
import pandas as pd 

lap=pd.read_csv("laptops.csv",encoding='latin1')
lap=lap.rename(columns={'Price (Euros)':'price'})# renaming the price column
lap['price']=lap['price'].str.replace(",",'.')
lap['price'] =pd.to_numeric(lap['price'])
del lap['Operating System Version']# delating a column
lap['Screen Size'] =lap['Screen Size'].str.replace('"','')
lap['Screen Size'] =pd.to_numeric(lap['Screen Size'])

# %% [markdown]
# loc and iloc method
# index position , i.e 0 ,1 ,2 ,3 ....
# index lebels /names,  i.e zero , one , two , three ...

# %% [markdown]
# loc(lebel) method

# %% [markdown]
# value--df.loc['zero']

# %% [markdown]
# list--df.loc[['zero','two']]

# %% [markdown]
# Slicing-- df.loc['zero':'two']

# %% [markdown]
# iloc(position) method

# %% [markdown]
# value-- df.iloc[0]

# %% [markdown]
# list-- df.loc[[0,2]]

# %% [markdown]
# slicing-- df.loc[0:2]
