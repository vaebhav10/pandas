# %%
import pandas as pd 
import numpy as np

# %%
stats=pd.read_csv('1customers-100.csv')

# %%
stats
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# ATTIBUTES

# %%
stats.shape
# Out:
# (100, 12)

# %%
stats.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
stats.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
stats.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# dtype: object

# %%
# METHODS

# %%
# showing the info of the dataframe 
stats.info
# Out:
# <bound method DataFrame.info of     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
stats.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
# FUNCTIONS

# %%
# number of rows 
len(stats)
# Out:
# 100

# %%
max(stats)
# Out:
# 'Website'

# %%
max(stats.index)
# Out:
# 99

# %%
min(stats.index)
# Out:
# 0

# %%
type(stats)
# Out:
# pandas.core.frame.DataFrame

# %%
round(stats,2)# rounding the values of the datasheet
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
#selecting one column

#1.1 syntax1

# %%
#selecting a column with [ ](preferred)
stats['Customer Id']
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
# check out the data type
type(stats['Customer Id'])
# Out:
# pandas.core.series.Series

# %%
# series : attributes and methods
stats['Customer Id'].index
stats['Customer Id'].head()
# Out:
# 0    DD37Cf93aecA6Dc
# 1    1Ef7b82A4CAAD10
# 2    6F94879bDAfE5a6
# 3    5Cef8BFA16c5e3c
# 4    053d585Ab6b3159
# Name: Customer Id, dtype: object

# %%
# syntax 2 
# selecting a column with . 

stats.City
# Out:
# 0          East Leonard
# 1     East Jimmychester
# 2         Isabelborough
# 3            Bensonview
# 4        West Priscilla
#             ...
# 95         East Richard
# 96         New Bradview
# 97           Ortegaland
# 98      Lake Elijahview
# 99            Judymouth
# Name: City, Length: 100, dtype: object

# %%
# selecting with . (pitfalls)
stats['Customer Id']
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
# selecting two or more columns

# %%
report=pd.read_csv('file.csv')

# %%
report
# Out:
#     Unnamed: 0       Student Name Exam Name        Date  Points
# 0          NaN      Vaibhav Kumar   Biology  05/06/2016   100.0
# 1          NaN      Velma Clemons   Biology  05/06/2016    43.0
# 2          NaN         kelly frye   Biology  05/06/2016    81.0
# 3          NaN        Louis Mcgee   Biology  05/06/2016    11.0
# 4          NaN       Phyllis Paul   Biology  05/06/2016    18.0
# 5          NaN     Zenaida Decker   Biology  05/06/2016    55.0
# 6          NaN    Gillian Tillman   Biology  05/06/2016    38.0
# 7          NaN    Constance Boone   Biology  05/06/2016    16.0
# 8          NaN  Giselle Lancaster   Biology  05/06/2016    73.0
# 9          NaN   Kirsten Mcdowell   Biology  05/06/2016    16.0
# 10         NaN                NaN       NaN         NaN     NaN
# 11         NaN                NaN       NaN         NaN     NaN
# 12         NaN         21/06/2025       NaN         NaN     NaN

# %%
report[['Student Name','Points']]# selecting two columns
# Out:
#          Student Name  Points
# 0       Vaibhav Kumar   100.0
# 1       Velma Clemons    43.0
# 2          kelly frye    81.0
# 3         Louis Mcgee    11.0
# 4        Phyllis Paul    18.0
# 5      Zenaida Decker    55.0
# 6     Gillian Tillman    38.0
# 7     Constance Boone    16.0
# 8   Giselle Lancaster    73.0
# 9    Kirsten Mcdowell    16.0
# 10                NaN     NaN
# 11                NaN     NaN
# 12         21/06/2025     NaN

# %%
report.Points# only one column can be selected using .
# Out:
# 0     100.0
# 1      43.0
# 2      81.0
# 3      11.0
# 4      18.0
# 5      55.0
# 6      38.0
# 7      16.0
# 8      73.0
# 9      16.0
# 10      NaN
# 11      NaN
# 12      NaN
# Name: Points, dtype: float64

# %%
# Adding a new column

# %%
report['status']="passed"

# %%
report
# Out:
#     Unnamed: 0       Student Name Exam Name        Date  Points
# 0          NaN      Vaibhav Kumar   Biology  05/06/2016   100.0
# 1          NaN      Velma Clemons   Biology  05/06/2016    43.0
# 2          NaN         kelly frye   Biology  05/06/2016    81.0
# 3          NaN        Louis Mcgee   Biology  05/06/2016    11.0
# 4          NaN       Phyllis Paul   Biology  05/06/2016    18.0
# 5          NaN     Zenaida Decker   Biology  05/06/2016    55.0
# 6          NaN    Gillian Tillman   Biology  05/06/2016    38.0
# 7          NaN    Constance Boone   Biology  05/06/2016    16.0
# 8          NaN  Giselle Lancaster   Biology  05/06/2016    73.0
# 9          NaN   Kirsten Mcdowell   Biology  05/06/2016    16.0
# 10         NaN                NaN       NaN         NaN     NaN
# 11         NaN                NaN       NaN         NaN     NaN
# 12         NaN         21/06/2025       NaN         NaN     NaN

# %%
report.status
# Out:
# 0     passed
# 1     passed
# 2     passed
# 3     passed
# 4     passed
# 5     passed
# 6     passed
# 7     passed
# 8     passed
# 9     passed
# 10    passed
# 11    passed
# 12    passed
# Name: status, dtype: object

# %%
# creating random integer numbers between 1 and 100
score =np.random .randint(1,100,size =13)

# %%
# min value inclusive and high value exclusive 

min(score )
max (score )
# Out:
# 88

# %%
# adding a new column to dataframe with an array 
report['score']=score
report
# Out:
#     Unnamed: 0       Student Name Exam Name        Date  Points  score
# 0          NaN      Vaibhav Kumar   Biology  05/06/2016   100.0     83
# 1          NaN      Velma Clemons   Biology  05/06/2016    43.0     10
# 2          NaN         kelly frye   Biology  05/06/2016    81.0     89
# 3          NaN        Louis Mcgee   Biology  05/06/2016    11.0     22
# 4          NaN       Phyllis Paul   Biology  05/06/2016    18.0     65
# 5          NaN     Zenaida Decker   Biology  05/06/2016    55.0     72
# 6          NaN    Gillian Tillman   Biology  05/06/2016    38.0     91
# 7          NaN    Constance Boone   Biology  05/06/2016    16.0     95
# 8          NaN  Giselle Lancaster   Biology  05/06/2016    73.0     26
# 9          NaN   Kirsten Mcdowell   Biology  05/06/2016    16.0     37
# 10         NaN                NaN       NaN         NaN     NaN     45
# 11         NaN                NaN       NaN         NaN     NaN      6
# ...
