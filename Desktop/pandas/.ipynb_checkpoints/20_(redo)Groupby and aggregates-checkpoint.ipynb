# %%
import pandas as pd

# %%
df=pd.read_csv('Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# 1      Passenger               28.40          3.2       225.0      108.1
# 2      Passenger                 NaN          3.2       225.0      106.9
# 3      Passenger               42.00          3.5       210.0      114.6
# 4      Passenger               23.99          1.8       150.0      102.6
# ..           ...                 ...          ...         ...        ...
# 152    Passenger               24.40          1.9       160.0      100.5
# 153    Passenger               27.50          2.4       168.0      104.9
# 154    Passenger               28.80          2.4       168.0      104.9
# 155    Passenger               45.50          2.3       236.0      104.9
# 156    Passenger               36.00          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0      2/2/2012
# 1     70.3   192.9        3.517           17.2             25.0      6/3/2011
# 2     70.6   192.0        3.470           17.2             26.0      1/4/2012
# 3     71.4   196.6        3.850           18.0             22.0     3/10/2011
# 4     68.2   178.0        2.998           16.4             27.0     10/8/2011
# ..     ...     ...          ...            ...              ...           ...
# 152   67.6   176.6        3.042           15.8             25.0     9/21/2011
# 153   69.3   185.9        3.208           17.9             25.0    11/24/2012
# 154   69.3   186.2        3.259           17.9             25.0     6/25/2011
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# 2                  NaN
# 3            91.389779
# 4            62.777639
# ..                 ...
# 152          66.498812
# 153          70.654495
# 154          71.155978
# 155         101.623357
# 156          85.735655
#
# [157 rows x 16 columns]

# %%
df=df[['Manufacturer','Sales_in_thousands','Vehicle_type','Price_in_thousands','Horsepower','Fuel_capacity']]

# %%
df.nunique()
# Out:
# Manufacturer           30
# Sales_in_thousands    157
# Vehicle_type            2
# Price_in_thousands    152
# Horsepower             66
# Fuel_capacity          55
# dtype: int64

# %% [markdown]
# 1 agg()

# %%
# calculate the sum of columns 
df.agg('sum')
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
# Vehicle_type          PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                             4245.567
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# dtype: object

# %%
# calculate the mean of numeric columns
df.select_dtypes(include=['number']).agg('mean')
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
# calculate the mean and count values
df.apply(['sum','count'])
# Out:
#                                             Manufacturer  Sales_in_thousands  \
# sum    AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...            8320.698
# count                                                157             157.000
#
#                                             Vehicle_type  Price_in_thousands  \
# sum    PassengerPassengerPassengerPassengerPassengerP...            4245.567
# count                                                157             155.000
#
#        Horsepower  Fuel_capacity
# sum       29008.0         2800.5
# count       156.0          156.0

# %%
# different aggregation per column : calculate the sum and mean of 'sales '
df.agg({'Sales_in_thousands':['sum','mean'],
        'Price_in_thousands':['sum','max']})
# Out:
#       Sales_in_thousands  Price_in_thousands
# sum          8320.698000            4245.567
# mean           52.998076                 NaN
# max                  NaN              85.500

# %%
# aggregate over the columns 
df[['Sales_in_thousands','Price_in_thousands']].agg('sum',axis=1)
# Out:
# 0      38.419
# 1      67.784
# 2      14.114
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
df['Sales_in_thousands']+df['Price_in_thousands']
# Out:
# 0      38.419
# 1      67.784
# 2         NaN
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
df.agg(x_sum=('Sales_in_thousands','sum'),
      y_mean=('Sales_in_thousands','mean'))
# Out:
#         Sales_in_thousands
# x_sum          8320.698000
# y_mean           52.998076

# %% [markdown]
# 2 The split-apply combine strategy

# %%
# split data into separate groups 
passenger_filter =df['Vehicle_type']=='passanger'
car_filter=df['Vehicle_type']=='Car'
df['Vehicle_type'].value_counts()
# Out:
# Vehicle_type
# Passanger    157
# Name: count, dtype: int64

# %%
# apply an operation
df[passanger_filter]['Sales_in_thousands'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # apply an operation
# ----> 2 df[passanger_filter]['Sales_in_thousands'].mean()
#
# NameError: name 'passanger_filter' is not defined
